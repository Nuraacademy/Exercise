# %% [markdown]
# <a href="https://colab.research.google.com/github/Nuraacademy/Exercise/blob/main/Example_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1. Print
#
# Here is the example below for

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Try yourself
# Now, try to write a code that will return `Hello Earth` as the output

# %%
# Your Code Here

# %% [markdown]
# #### Check Answer

# %%
print("Hello Earth")
